# %%
# %run ../codes/utils.py

# %% [markdown]
# ## 450 Airports Influences (sum from each layer)

# %%
# import the library
import folium
import pandas as pd
import numpy as np

m = folium.Map(location=[53,13], tiles="OpenStreetMap", zoom_start=4.1)
data = pd.read_csv('../datasets/EUAir/EUAirTransportation_nodes.txt', sep=" ")
data['weight'] = np.sum(EUAir, axis=0) + 1

for i in range(0,len(data)):

    # Skip unconnected airports.

    if data.iloc[i]['weight'] > 1:
        folium.Circle(
            location=[data.iloc[i]['nodeLat'], data.iloc[i]['nodeLong']],
            popup=data.iloc[i]['nodeLabel'],
            radius=float(data.iloc[i]['weight'])*4000,
            color="#3186cc",
            fill=True,
            fill_color="#FFFFFF",
        ).add_to(m)

# Show map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## 37 Airports Influences (sum of each layer)

# %%
g = len(EUAir)
LayerInfl = np.zeros(g, dtype=float)
for i in range(g):
    LayerInfl[i] = np.sum(EUAir[i])
Airlines = pd.read_csv('../datasets/EUAir/EUAirTransportation_layers.txt', sep=" ")
Airlines['weight'] = LayerInfl
Airlines.sort_values(by=['weight'], ascending=False)
# Out:
#     nodeID                      nodeLabel      weight
# 1        2                        Ryanair  102.179270
# 0        1                      Lufthansa   62.117700
# 25      26                        Netjets   50.296507
# 2        3                        Easyjet   45.330904
# 5        6                     Air_Berlin   33.477084
# 6        7                     Air_France   28.850990
# 34      35                        Wideroe   28.698312
# 7        8          Scandinavian_Airlines   26.980030
# 35      36                    TNT_Airways   25.943550
# 15      16                       Wizz_Air   25.734955
# 12      13          Norwegian_Air_Shuttle   25.613212
# 31      32         European_Air_Transport   24.764186
# 36      37                    Olympic_Air   23.579929
# 4        5               Turkish_Airlines   22.345284
# 14      15                          Flybe   22.344312
# 26      27              Transavia_Holland   21.759803
# ...
